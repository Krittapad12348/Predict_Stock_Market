# %% [markdown]
# # Predict The Stock Market Using Machine Learning

# %% [markdown]
# In this project, I will work with time series data which is S&P 500 index. I get the dataframe by using yfinance package. Each row of datafrme is the price on asingle trading day from year 1950 to 2022. Here are the columns:
# - Open: Indicates the price when the market opened.
# - High: Highest price during the day.
# - Low: Lowest price during the day.
# - Close: Indicates the price when the exchange closed.
# - Volume: Indicates the total number of shares traded.

# %% [markdown]
# **Goal** : To predict the index whether go up or down

# %%
# Install and import modules
# !pip install os
# !pip install yfinance
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix
import yfinance as yf
import pandas as pd
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
import os
# Out:
# ERROR: Could not find a version that satisfies the requirement os (from versions: none)
# ERROR: No matching distribution found for os
# Requirement already satisfied: yfinance in c:\users\por\anaconda3\lib\site-packages (0.2.12)
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\por\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: requests>=2.26 in c:\users\por\anaconda3\lib\site-packages (from yfinance) (2.28.1)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\por\anaconda3\lib\site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: html5lib>=1.1 in c:\users\por\anaconda3\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\por\anaconda3\lib\site-packages (from yfinance) (4.11.1)
# Requirement already satisfied: cryptography>=3.3.2 in c:\users\por\anaconda3\lib\site-packages (from yfinance) (37.0.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\por\anaconda3\lib\site-packages (from yfinance) (2.3.5)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\por\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\por\anaconda3\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\por\anaconda3\lib\site-packages (from yfinance) (1.21.5)
# Requirement already satisfied: pytz>=2022.5 in c:\users\por\anaconda3\lib\site-packages (from yfinance) (2022.7.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\por\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\por\anaconda3\lib\site-packages (from cryptography>=3.3.2->yfinance) (1.15.1)
# Requirement already satisfied: six>=1.9 in c:\users\por\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\por\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\por\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\por\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\por\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\por\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\por\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2022.9.14)
# Requirement already satisfied: pycparser in c:\users\por\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=3.3.2->yfinance) (2.21)

# %%
# Check if we have csv file already, if not go download it.
if os.path.exists("sp500.csv"):
    sp500 = pd.read_csv("sp500.csv", index_col=0)
else:
    sp500 = yf.Ticker("^GSPC")
    sp500 = sp500.history(period="max")
    sp500.to_csv("sp500.csv")
sp500
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 1950-01-03    16.660000    16.660000    16.660000    16.660000     1260000
# 1950-01-04    16.850000    16.850000    16.850000    16.850000     1890000
# 1950-01-05    16.930000    16.930000    16.930000    16.930000     2550000
# 1950-01-06    16.980000    16.980000    16.980000    16.980000     2010000
# 1950-01-09    17.080000    17.080000    17.080000    17.080000     2520000
# ...                 ...          ...          ...          ...         ...
# 2022-05-10  4035.179932  4068.820068  3958.169922  4001.050049  4630150000
# 2022-05-11  3990.080078  4049.090088  3928.820068  3935.179932  4683220000
# 2022-05-12  3903.949951  3964.800049  3858.870117  3930.080078  4964130000
# 2022-05-13  3963.899902  4038.879883  3963.899902  4023.889893  4142950000
# 2022-05-16  4013.020020  4046.459961  3983.989990  4008.010010  2203333000
#
#             Dividends  Stock Splits
# Date
# 1950-01-03          0             0
# 1950-01-04          0             0
# 1950-01-05          0             0
# 1950-01-06          0             0
# 1950-01-09          0             0
# ...               ...           ...
# 2022-05-10          0             0
# 2022-05-11          0             0
# 2022-05-12          0             0
# 2022-05-13          0             0
# 2022-05-16          0             0
#
# [18211 rows x 7 columns]

# %% [markdown]
# # Explore data and data cleaning

# %% [markdown]
# - Drop Dividends,Stock Splits columns.
# - Plot time series of Close price.
# - Generate target column.
# - Change index type of dataframe to datatime.
# - Filter old data (before 1990) out.

# %%
# Drop some columns that we're not going to use. These 2 columns are more apporpriate for individual stock not for index
sp500 = sp500.drop(['Dividends','Stock Splits'], axis = 1)
sp500
# Out:
#                    Open         High          Low        Close      Volume
# Date
# 1950-01-03    16.660000    16.660000    16.660000    16.660000     1260000
# 1950-01-04    16.850000    16.850000    16.850000    16.850000     1890000
# 1950-01-05    16.930000    16.930000    16.930000    16.930000     2550000
# 1950-01-06    16.980000    16.980000    16.980000    16.980000     2010000
# 1950-01-09    17.080000    17.080000    17.080000    17.080000     2520000
# ...                 ...          ...          ...          ...         ...
# 2022-05-10  4035.179932  4068.820068  3958.169922  4001.050049  4630150000
# 2022-05-11  3990.080078  4049.090088  3928.820068  3935.179932  4683220000
# 2022-05-12  3903.949951  3964.800049  3858.870117  3930.080078  4964130000
# 2022-05-13  3963.899902  4038.879883  3963.899902  4023.889893  4142950000
# 2022-05-16  4013.020020  4046.459961  3983.989990  4008.010010  2203333000
#
# [18211 rows x 5 columns]

# %%
# Explore data
# %matplotlib inline
sp500.plot.line(y='Close', use_index = True)
plt.xticks(rotation = 45)
plt.show()

# %%
# Create target column by shift Close column -1 period as tommorrow
sp500['tomorrow'] = sp500['Close'].shift(periods= -1, axis=0)
sp500
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 1950-01-03    16.660000    16.660000    16.660000    16.660000     1260000
# 1950-01-04    16.850000    16.850000    16.850000    16.850000     1890000
# 1950-01-05    16.930000    16.930000    16.930000    16.930000     2550000
# 1950-01-06    16.980000    16.980000    16.980000    16.980000     2010000
# 1950-01-09    17.080000    17.080000    17.080000    17.080000     2520000
# ...                 ...          ...          ...          ...         ...
# 2022-05-10  4035.179932  4068.820068  3958.169922  4001.050049  4630150000
# 2022-05-11  3990.080078  4049.090088  3928.820068  3935.179932  4683220000
# 2022-05-12  3903.949951  3964.800049  3858.870117  3930.080078  4964130000
# 2022-05-13  3963.899902  4038.879883  3963.899902  4023.889893  4142950000
# 2022-05-16  4013.020020  4046.459961  3983.989990  4008.010010  2203333000
#
#                tomorrow
# Date
# 1950-01-03    16.850000
# 1950-01-04    16.930000
# 1950-01-05    16.980000
# 1950-01-06    17.080000
# 1950-01-09    17.030001
# ...                 ...
# 2022-05-10  3935.179932
# 2022-05-11  3930.080078
# 2022-05-12  4023.889893
# 2022-05-13  4008.010010
# 2022-05-16          NaN
#
# [18211 rows x 6 columns]

# %%
# Then compare close column and tomorrow as a target column (go up = 1, go down = 0)
sp500['target'] = (sp500['Close'] < sp500['tomorrow']).astype(int)
sp500
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 1950-01-03    16.660000    16.660000    16.660000    16.660000     1260000
# 1950-01-04    16.850000    16.850000    16.850000    16.850000     1890000
# 1950-01-05    16.930000    16.930000    16.930000    16.930000     2550000
# 1950-01-06    16.980000    16.980000    16.980000    16.980000     2010000
# 1950-01-09    17.080000    17.080000    17.080000    17.080000     2520000
# ...                 ...          ...          ...          ...         ...
# 2022-05-10  4035.179932  4068.820068  3958.169922  4001.050049  4630150000
# 2022-05-11  3990.080078  4049.090088  3928.820068  3935.179932  4683220000
# 2022-05-12  3903.949951  3964.800049  3858.870117  3930.080078  4964130000
# 2022-05-13  3963.899902  4038.879883  3963.899902  4023.889893  4142950000
# 2022-05-16  4013.020020  4046.459961  3983.989990  4008.010010  2203333000
#
#                tomorrow  target
# Date
# 1950-01-03    16.850000       1
# 1950-01-04    16.930000       1
# 1950-01-05    16.980000       1
# 1950-01-06    17.080000       1
# 1950-01-09    17.030001       0
# ...                 ...     ...
# 2022-05-10  3935.179932       0
# 2022-05-11  3930.080078       0
# 2022-05-12  4023.889893       1
# 2022-05-13  4008.010010       0
# 2022-05-16          NaN       0
#
# [18211 rows x 7 columns]

# %%
# Change index of dataframe to datetime type 
sp500.index = sp500.index.astype('datetime64[ns]')
# Because old data cant be useful for the prediction and the market could have shift fundamentally. We select year more than 1990 analyze from graph above
sp500 = sp500.copy()[sp500.index.year >= 1990]
sp500
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 1990-01-02   353.399994   359.690002   351.980011   359.690002   162070000
# 1990-01-03   359.690002   360.589996   357.890015   358.760010   192330000
# 1990-01-04   358.760010   358.760010   352.890015   355.670013   177000000
# 1990-01-05   355.670013   355.670013   351.350006   352.200012   158530000
# 1990-01-08   352.200012   354.239990   350.540009   353.790009   140110000
# ...                 ...          ...          ...          ...         ...
# 2022-05-10  4035.179932  4068.820068  3958.169922  4001.050049  4630150000
# 2022-05-11  3990.080078  4049.090088  3928.820068  3935.179932  4683220000
# 2022-05-12  3903.949951  3964.800049  3858.870117  3930.080078  4964130000
# 2022-05-13  3963.899902  4038.879883  3963.899902  4023.889893  4142950000
# 2022-05-16  4013.020020  4046.459961  3983.989990  4008.010010  2203333000
#
#                tomorrow  target
# Date
# 1990-01-02   358.760010       0
# 1990-01-03   355.670013       0
# 1990-01-04   352.200012       0
# 1990-01-05   353.790009       1
# 1990-01-08   349.619995       0
# ...                 ...     ...
# 2022-05-10  3935.179932       0
# 2022-05-11  3930.080078       0
# 2022-05-12  4023.889893       1
# 2022-05-13  4008.010010       0
# 2022-05-16          NaN       0
#
# [8157 rows x 7 columns]

# %% [markdown]
# # Training an Initial Machine Learning Model

# %% [markdown]
# - Instantiate model (Randomforest) for classifier problem
# - Split train / test data (100 rows for test data)
# - Select predictors and target
# - measure errors by using recall

# %%
# Instantiate model (Randomforest), train, test data 
rf = RandomForestClassifier(n_estimators= 100,random_state = 1, min_samples_split=100)
train = sp500.copy().iloc[:-100]
test = sp500.copy().iloc[-100:]
train
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 1990-01-02   353.399994   359.690002   351.980011   359.690002   162070000
# 1990-01-03   359.690002   360.589996   357.890015   358.760010   192330000
# 1990-01-04   358.760010   358.760010   352.890015   355.670013   177000000
# 1990-01-05   355.670013   355.670013   351.350006   352.200012   158530000
# 1990-01-08   352.200012   354.239990   350.540009   353.790009   140110000
# ...                 ...          ...          ...          ...         ...
# 2021-12-15  4636.459961  4712.600098  4611.220215  4709.850098  3367580000
# 2021-12-16  4719.129883  4731.990234  4651.890137  4668.669922  3592810000
# 2021-12-17  4652.500000  4666.700195  4600.220215  4620.640137  5609780000
# 2021-12-20  4587.899902  4587.899902  4531.100098  4568.020020  3395780000
# 2021-12-21  4594.959961  4651.140137  4583.160156  4649.229980  2564370000
#
#                tomorrow  target
# Date
# 1990-01-02   358.760010       0
# 1990-01-03   355.670013       0
# 1990-01-04   352.200012       0
# 1990-01-05   353.790009       1
# 1990-01-08   349.619995       0
# ...                 ...     ...
# 2021-12-15  4668.669922       0
# 2021-12-16  4620.640137       0
# 2021-12-17  4568.020020       0
# 2021-12-20  4649.229980       1
# 2021-12-21  4696.560059       1
#
# [8057 rows x 7 columns]

# %%
test
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 2021-12-22  4650.359863  4697.669922  4645.529785  4696.560059  2439570000
# 2021-12-23  4703.959961  4740.740234  4703.959961  4725.790039  2194630000
# 2021-12-27  4733.990234  4791.490234  4733.990234  4791.189941  2264120000
# 2021-12-28  4795.490234  4807.020020  4780.040039  4786.350098  2217050000
# 2021-12-29  4788.640137  4804.060059  4778.080078  4793.060059  2369370000
# ...                 ...          ...          ...          ...         ...
# 2022-05-10  4035.179932  4068.820068  3958.169922  4001.050049  4630150000
# 2022-05-11  3990.080078  4049.090088  3928.820068  3935.179932  4683220000
# 2022-05-12  3903.949951  3964.800049  3858.870117  3930.080078  4964130000
# 2022-05-13  3963.899902  4038.879883  3963.899902  4023.889893  4142950000
# 2022-05-16  4013.020020  4046.459961  3983.989990  4008.010010  2203333000
#
#                tomorrow  target
# Date
# 2021-12-22  4725.790039       1
# 2021-12-23  4791.189941       1
# 2021-12-27  4786.350098       0
# 2021-12-28  4793.060059       1
# 2021-12-29  4778.729980       0
# ...                 ...     ...
# 2022-05-10  3935.179932       0
# 2022-05-11  3930.080078       0
# 2022-05-12  4023.889893       1
# 2022-05-13  4008.010010       0
# 2022-05-16          NaN       0
#
# [100 rows x 7 columns]

# %%
train_tg = train['target']
train_col = train.copy().drop(['tomorrow','target'],axis=1)
test_tg = test['target']
test_col = test.copy().drop(['tomorrow','target'],axis=1)
rf.fit(train_col,train_tg)
pred = rf.predict(test_col)
predict = pd.Series(pred, index = test.index)
train.shape
# Out:
# (8057, 7)

# %%
test_col
# Out:
#                    Open         High          Low        Close      Volume
# Date
# 2021-12-22  4650.359863  4697.669922  4645.529785  4696.560059  2439570000
# 2021-12-23  4703.959961  4740.740234  4703.959961  4725.790039  2194630000
# 2021-12-27  4733.990234  4791.490234  4733.990234  4791.189941  2264120000
# 2021-12-28  4795.490234  4807.020020  4780.040039  4786.350098  2217050000
# 2021-12-29  4788.640137  4804.060059  4778.080078  4793.060059  2369370000
# ...                 ...          ...          ...          ...         ...
# 2022-05-10  4035.179932  4068.820068  3958.169922  4001.050049  4630150000
# 2022-05-11  3990.080078  4049.090088  3928.820068  3935.179932  4683220000
# 2022-05-12  3903.949951  3964.800049  3858.870117  3930.080078  4964130000
# 2022-05-13  3963.899902  4038.879883  3963.899902  4023.889893  4142950000
# 2022-05-16  4013.020020  4046.459961  3983.989990  4008.010010  2203333000
#
# [100 rows x 5 columns]

# %%
from sklearn.metrics import precision_recall_fscore_support
precision_recall_fscore_support(test_tg,predict)
# Out:
# (array([0.52173913, 0.41558442]),
#  array([0.21052632, 0.74418605]),
#  array([0.3       , 0.53333333]),
#  array([57, 43], dtype=int64))

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_tg,predict)
# Out:
# 0.44

# %%
from sklearn.metrics import precision_score
precision_score(test_tg,predict)
# Out:
# 0.4155844155844156

# %%
from sklearn.metrics import recall_score
recall_score(test_tg,predict)
# Out:
# 0.7441860465116279

# %%
combined = pd.concat([test_tg,predict],axis=1)
combined.columns = ['target','predict']
combined
# Out:
#             target  predict
# Date
# 2021-12-22       1        1
# 2021-12-23       1        0
# 2021-12-27       0        0
# 2021-12-28       1        0
# 2021-12-29       0        0
# ...            ...      ...
# 2022-05-10       0        1
# 2022-05-11       0        0
# 2022-05-12       1        0
# 2022-05-13       0        1
# 2022-05-16       0        1
#
# [100 rows x 2 columns]

# %%
combined.plot.line()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# This graph is target vs prediction values along with date.
# It seems that our prediction is going up but the target is going down. Our model is not good enough.
# So we need improvement.

# %% [markdown]
# # Model Improvement

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors],train['target'])
    predict = model.predict(test[predictors])
    predict = pd.Series(predict, index = test.index, name= 'predictions')
    combined = pd.concat([test['target'], predict], axis= 1)
    return combined

# %%
def backtest(data, model, predictors, start=2500, step = 250): #assume 1 year = 250 days trade start at 10 years and plus 1 year over
    all_predictions  = []
    for i in range(start, data.shape[0], step):
        train = data.iloc[:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    return pd.concat(all_predictions)
predictors = ['Open','High','Low','Close','Volume']
predict = backtest(sp500,rf,predictors)

# %%
predict['predictions'].value_counts()
# Out:
# 0    3305
# 1    2352
# Name: predictions, dtype: int64

# %%
precision_score(predict['target'],predict['predictions'])
# Out:
# 0.5314625850340136

# %%
predict['target'].value_counts() / predict.shape[0]
# Out:
# 1    0.536857
# 0    0.463143
# Name: target, dtype: float64

# %%
# generate another predictors
horizons = [2,5,60,250,1000]
for horizon in horizons:
    rolling_avg = sp500.rolling(horizon).mean()
    ratio_column = f'close_ratio_{horizon}'
    sp500[ratio_column] = sp500['Close'] / rolling_avg['Close']
    trend_column = f'trend_{horizon}'
    sp500[trend_column] = sp500.shift(1).rolling(horizon).sum()['target']
predictors = [ratio_column,trend_column]

# %%
sp500 = sp500.dropna()
sp500
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 1993-12-14   465.730011   466.119995   462.459991   463.059998   275050000
# 1993-12-15   463.059998   463.690002   461.839996   461.839996   331770000
# 1993-12-16   461.859985   463.980011   461.859985   463.339996   284620000
# 1993-12-17   463.339996   466.380005   463.339996   466.380005   363750000
# 1993-12-20   466.380005   466.899994   465.529999   465.850006   255900000
# ...                 ...          ...          ...          ...         ...
# 2022-05-09  4081.270020  4081.270020  3975.479980  3991.239990  4746120000
# 2022-05-10  4035.179932  4068.820068  3958.169922  4001.050049  4630150000
# 2022-05-11  3990.080078  4049.090088  3928.820068  3935.179932  4683220000
# 2022-05-12  3903.949951  3964.800049  3858.870117  3930.080078  4964130000
# 2022-05-13  3963.899902  4038.879883  3963.899902  4023.889893  4142950000
#
#                tomorrow  target  close_ratio_2  trend_2  close_ratio_5  \
# Date
# 1993-12-14   461.839996       0       0.997157      1.0       0.996617
# 1993-12-15   463.339996       1       0.998681      0.0       0.995899
# 1993-12-16   466.380005       1       1.001621      1.0       0.999495
# 1993-12-17   465.850006       0       1.003270      2.0       1.004991
# 1993-12-20   465.299988       0       0.999431      1.0       1.003784
# ...                 ...     ...            ...      ...            ...
# 2022-05-09  4001.050049       1       0.983721      0.0       0.962343
# 2022-05-10  3935.179932       0       1.001227      1.0       0.972892
# 2022-05-11  3930.080078       0       0.991700      1.0       0.974166
# 2022-05-12  4023.889893       1       0.999352      0.0       0.983460
# 2022-05-13  4008.010010       0       1.011794      1.0       1.011971
#
#             trend_5  close_ratio_60  trend_60  close_ratio_250  trend_250  \
# Date
# 1993-12-14      1.0        1.000283      32.0         1.028047      127.0
# 1993-12-15      1.0        0.997329      32.0         1.025151      126.0
# 1993-12-16      2.0        1.000311      32.0         1.028274      127.0
# 1993-12-17      3.0        1.006561      32.0         1.034781      128.0
# 1993-12-20      2.0        1.005120      32.0         1.033359      128.0
# ...             ...             ...       ...              ...        ...
# 2022-05-09      2.0        0.914756      26.0         0.898738      132.0
# 2022-05-10      2.0        0.918469      27.0         0.901037      132.0
# 2022-05-11      1.0        0.904963      27.0         0.886394      131.0
# 2022-05-12      1.0        0.905668      26.0         0.885431      131.0
# 2022-05-13      2.0        0.928896      26.0         0.906651      132.0
#
#             close_ratio_1000  trend_1000
# Date
# 1993-12-14          1.176082       512.0
# 1993-12-15          1.172676       512.0
# 1993-12-16          1.176163       513.0
# 1993-12-17          1.183537       514.0
# 1993-12-20          1.181856       513.0
# ...                      ...         ...
# 2022-05-09          1.158960       553.0
# 2022-05-10          1.161381       553.0
# 2022-05-11          1.141860       553.0
# 2022-05-12          1.139984       552.0
# 2022-05-13          1.166756       553.0
#
# [7156 rows x 17 columns]

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors],train['target'])
    predict = model.predict_proba(test[predictors])[:,1]
    predict[predict >= 0.6] = 1
    predict[predict < 0.6] = 0
    predict = pd.Series(predict, index = test.index, name= 'predictions')
    combined = pd.concat([test['target'], predict], axis= 1)
    return combined

# %%
model = RandomForestClassifier(n_estimators= 100,random_state = 1, min_samples_split=100)
prediction = backtest(sp500, model, predictors)

# %%
prediction['predictions'].value_counts()
# Out:
# 0.0    3517
# 1.0    1139
# Name: predictions, dtype: int64

# %%
precision_score(prediction['target'],prediction['predictions'])
# Out:
# 0.5100965759438104
